# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Tue Aug  1 03:11:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'A121 Datasheet (1).pdf'		  MR60BHA1_usermanual.zip
#  A121-Setup.gslides			 'My Drive'
# 'Colab Notebooks'			  my_model.h5
# 'Data (1).zip'				 'pcb (1).xmodel'
#  datan.zip				 'PCB Design_NFC Card.gslides'
#  Data.zip				 'PCB etching.gslides'
# 'Etching Workshop[1] (1).gslides'	  pcb.xmodel
# 'Etching Workshop[1] (2).gslides'	  Procedure.gdoc
# 'Etching Workshop[1].gslides'		  Seeed-mmWave-sensor-series-V2.0.pptx
# 'Etching Workshop.gslides'		 'Test Rundown Schedule.gdoc'
#  fastai-resnet50.ipynb			 'University Stuff'
# 'Food recognition'			 'Untitled document.gdoc'
# 'HLK-LD6001 Sensor.gslides'		 'Untitled spreadsheet (1).gsheet'
# 'keras-YOLOv3-model-set-master (1).zip'  'Untitled spreadsheet.gsheet'
#  lab_manual3.gdoc			  VID_20230223_172850.mp4
#  lab_manual.gdoc			  vitis-ai.gslides
#  LAng2030h.gdoc				  yolov3
# 'Lang2030h innovation project.gdoc'	 'Your big idea (1).gslides'
# 'md5sum (1).txt'			 'Your big idea (2).gslides'
# ...

# %% [markdown]
# **1) Clone, configure & compile Darknet**

# %%
# Clone
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15530, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15530 (delta 6), reused 10 (delta 4), pack-reused 15514
# Receiving objects: 100% (15530/15530), 14.21 MiB | 19.43 MiB/s, done.
# Resolving deltas: 100% (10418/10418), done.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# Compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# **2) Configure yolov3.cfg file**

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 14000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3_training.cfg

# %% [markdown]
# **3) Create .names and .data files**

# %%
# !echo -e 'PCB\nCopper' > data/obj.names
# !echo -e 'classes= 2\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov3' > data/obj.data

# %% [markdown]
# **4) Save yolov3_training.cfg and obj.names files in Google drive**

# %%
# !cp cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_testing.cfg
# !cp data/obj.names /mydrive/yolov3/classes.txt

# %% [markdown]
# **5) Create a folder and unzip image dataset**

# %%
# !mkdir data/obj
# !unzip /mydrive/yolov3/test7.zip -d data/obj
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/obj/test7/object7749.jpg
#   inflating: data/obj/test7/object7749.txt
#   inflating: data/obj/test7/object775.jpg
#   inflating: data/obj/test7/object775.txt
#   inflating: data/obj/test7/object7750.jpg
#   inflating: data/obj/test7/object7750.txt
#   inflating: data/obj/test7/object7751.jpg
#   inflating: data/obj/test7/object7751.txt
#   inflating: data/obj/test7/object7752.jpg
#   inflating: data/obj/test7/object7752.txt
#   inflating: data/obj/test7/object7753.jpg
#   inflating: data/obj/test7/object7753.txt
#   inflating: data/obj/test7/object7754.jpg
#   inflating: data/obj/test7/object7754.txt
#   inflating: data/obj/test7/object7755.jpg
#   inflating: data/obj/test7/object7755.txt
#   inflating: data/obj/test7/object7756.jpg
#   inflating: data/obj/test7/object7756.txt
#   inflating: data/obj/test7/object7757.jpg
#   inflating: data/obj/test7/object7757.txt
#   inflating: data/obj/test7/object7758.jpg
# ...

# %% [markdown]
# **6) Create train.txt file**

# %%
import glob
images_list = glob.glob("data/obj/test7/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %% [markdown]
# **7) Download pre-trained weights for the convolutional layers file**

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2023-08-01 02:54:41--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  54.7MB/s    in 2.8s
#
# 2023-08-01 02:54:44 (54.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# **8) Start training**

# %%
# !./darknet detetor train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3/yolov3_training_last.weights -dont_show
# Out:
#  CUDA-version: 11080 (12000), cuDNN: 8.9.0, GPU count: 1
#  OpenCV version: 4.5.4
# Not an option: detetor
